# %% [markdown]
# <a href="https://colab.research.google.com/github/neerajguleria1/driver-drowsiness-detection/blob/main/Day15_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Task
'''Finding the missing(NaN) value'''
import pandas as pd
import numpy as np

dataset={
    'Users':['Neeraj','Sujal','Arpit','Amit'],
    'User1':[120,234,550,22],
    'User2':[420,231,np.nan,227],
    'User3':[220,274,560,242],
    'User4':[720,np.nan,55,np.nan]
}
df=pd.DataFrame(dataset)
print(df)
check_data=df.isna().sum()#It count the sum of missing values
print(check_data)
df.fillna(df.mean(numeric_only=True),inplace=True) # inplace true means it place operations directly on the dataframe not make a copy

df['AverageData']=df[["User1","User2","User3","User4"]].mean(axis=1)
df[df["AverageData"]>100]
# Out:
#     Users  User1  User2  User3  User4
# 0  Neeraj    120  420.0    220  720.0
# 1   Sujal    234  231.0    274    NaN
# 2   Arpit    550    NaN    560   55.0
# 3    Amit     22  227.0    242    NaN
# Users    0
# User1    0
# User2    1
# User3    0
# User4    2
# dtype: int64
#     Users  User1       User2  User3  User4  AverageData
# 0  Neeraj    120  420.000000    220  720.0   370.000000
# 1   Sujal    234  231.000000    274  387.5   281.625000
# 2   Arpit    550  292.666667    560   55.0   364.416667
# 3    Amit     22  227.000000    242  387.5   219.625000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_57['User1'].plot(kind='hist', bins=20, title='User1')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_58['User2'].plot(kind='hist', bins=20, title='User2')
# ...

# %%
from matplotlib import pyplot as plt
_df_57['User1'].plot(kind='hist', bins=20, title='User1')
plt.gca().spines[['top', 'right',]].set_visible(False)
