# %% [markdown]
# <a href="https://colab.research.google.com/github/neerajguleria1/Python-Learning/blob/main/day10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# File Handling in Python

from google.colab import files
uploaded = files.upload()

file=open("data1.txt","r")
content=file.read()
print(content)
file.close()
# Out:
#      <input type="file" id="files-680ad308-4136-48da-8fb4-dd22ab738f94" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-680ad308-4136-48da-8fb4-dd22ab738f94">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Upload files from our computer

from google.colab import files
print("Choose files to upload we can se their name printed after uploaded")
uploaded=files.upload()
print("Upload filesName:",list(uploaded.keys()))
# Out:
# Choose files to upload we can se their name printed after uploaded
#      <input type="file" id="files-ff06e03f-acf3-4ed7-b8ff-f3857917d061" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ff06e03f-acf3-4ed7-b8ff-f3857917d061">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
from google.colab import files
uploaded=files.upload()

filename=list(uploaded.keys())[0]
print("reading:",filename)

with open(filename,"r",encoding="utf-8") as f:
  data=f.read()
print("file head")
print(data)
# Out:
#      <input type="file" id="files-8cf48d4a-3da7-4f98-a237-b76ea56d53fc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8cf48d4a-3da7-4f98-a237-b76ea56d53fc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Cell 4 — write driver logs to a file
drivers = [
    {"name": "Neeraj", "speed": 180, "seatbelt": True},
    {"name": "Amit",  "speed": 220, "seatbelt": False},
    {"name": "Sujal", "speed": 140, "seatbelt": True},
]

with open("driver_log.txt","w",encoding="utf-8") as f:
  for d in drivers:
    if d["speed"]>200 and not d["seatbelt"]:
      f.write(f"{d['name']}- Overspeeding and no seatbelt ")
    elif d["speed"]>150:
      f.write(f"{d['name']}-Overspeeding ")
    else:
      f.write(f"{d['name']} is going normally ")

print("driver_log.txt created successfully")
# !ls -la driver_log.txt
# Out:
# driver_log.txt created successfully
# -rw-r--r-- 1 root root 79 Oct 16 18:49 driver_log.txt

# %%
with open("driver_log.txt","r",encoding="utf-8") as f:
  print(f.read());
# Out:
# Neeraj-Overspeeding Amit- Overspeeding and no seatbelt Sujal is going normally

# %%
new_event={"name":"Arpit","speed":330,"seatbelt":True}

with open("driver_log.txt","a",encoding="utf-8") as f:
  if new_event["speed"]>220 and not new_event["seatbelt"]:
    f.write(f"{new_event['name']} - Overspeeding ")
  else:
    f.write(f"{new_event['name']}- going normally")
print("appended new_event to driver_log.txt")

with open("driver_log.txt","r",encoding="utf-8") as f:
  print(f.read())
# Out:
# appended new_event to driver_log.txt
# Neeraj-Overspeeding Amit- Overspeeding and no seatbelt Sujal is going normally Arpit- going normally

# %%
# Download files to local computer
from google.colab import files
files.download("driver_log.txt")

# %%
# Work with CSV and JSON

import csv,json, pandas as pd

csv_file="driver.csv"
drivers = [
    {"name": "Alice", "speed": 55, "seatbelt": True},
    {"name": "Bob", "speed": 95, "seatbelt": False},
    {"name": "Charlie", "speed": 118, "seatbelt": True}
]


with open(csv_file,"w",newline="",encoding="utf-8") as f:
  writer=csv.DictWriter(f,fieldnames=["name","speed","seatbelt"])
  writer.writeheader()
  writer.writerows(drivers)

json_file="driver.json"
with open(json_file,"w",encoding='utf-8') as f:
  json.dump(drivers,f,indent=2)

print("CSV preview:")
display(pd.read_csv(csv_file))
print("JSON preview:")
display(pd.read_json(json_file))

# %%
import csv,json
import pandas as pd
employees = [
    {"name": "Amit Sharma", "department": "Engineering", "age": 29, "full_time": True},
    {"name": "Priya Mehta", "department": "Marketing", "age": 34, "full_time": True},
    {"name": "Ravi Kumar", "department": "Sales", "age": 41, "full_time": False},
    {"name": "Sneha Reddy", "department": "HR", "age": 27, "full_time": True},
    {"name": "Karan Singh", "department": "Finance", "age": 38, "full_time": True},
    {"name": "Neha Joshi", "department": "Design", "age": 25, "full_time": False},
    {"name": "Arjun Verma", "department": "Engineering", "age": 32, "full_time": True},
    {"name": "Divya Patel", "department": "Support", "age": 30, "full_time": True},
    {"name": "Manish Thakur", "department": "Operations", "age": 36, "full_time": False},
    {"name": "Isha Kapoor", "department": "Legal", "age": 40, "full_time": True}
]

csv_file= "employees.csv"
with open(csv_file,"w",newline="",encoding="utf-8") as f:
  writer=csv.DictWriter(f,fieldnames=["name","department","age","full_time"])
  writer.writeheader()
  writer.writerows(employees)

json_file= "employees.json"
with open(json_file,"w",encoding="utf-8") as f:
  json.dump(employees,f,indent=2)

print("CSV preview:")
display(pd.read_csv(csv_file))
print("Json preview:")
display(pd.read_json(json_file))
# Out:
# CSV preview:
#             name   department  age  full_time
# 0    Amit Sharma  Engineering   29       True
# 1    Priya Mehta    Marketing   34       True
# 2     Ravi Kumar        Sales   41      False
# 3    Sneha Reddy           HR   27       True
# 4    Karan Singh      Finance   38       True
# 5     Neha Joshi       Design   25      False
# 6    Arjun Verma  Engineering   32       True
# 7    Divya Patel      Support   30       True
# 8  Manish Thakur   Operations   36      False
# 9    Isha Kapoor        Legal   40       True
# Json preview:
#             name   department  age  full_time
# 0    Amit Sharma  Engineering   29       True
# 1    Priya Mehta    Marketing   34       True
# 2     Ravi Kumar        Sales   41      False
# 3    Sneha Reddy           HR   27       True
# 4    Karan Singh      Finance   38       True
# 5     Neha Joshi       Design   25      False
# 6    Arjun Verma  Engineering   32       True
# 7    Divya Patel      Support   30       True
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# !cp driver_log.txt /content/drive/MyDrive/drive_log.txt
print("Copied driver_log.txt to our google drive (Mydrive/drive_log.txt)")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# cp: cannot stat 'driver_log.txt': No such file or directory
# Copied driver_log.txt to our google drive (Mydrive/drive_log.txt)

# %%
from IPython.display import FileLink
display(FileLink('/content/drive/MyDrive/drive_log.txt'))
# Out:
# /content/drive/MyDrive/drive_log.txt
